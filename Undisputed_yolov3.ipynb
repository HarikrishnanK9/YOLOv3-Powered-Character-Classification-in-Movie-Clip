# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikrishnanK9/YOLOv3-Powered-Character-Classification-in-Movie-Clip/blob/main/Undisputed_yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Dec 13 07:07:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 17.23 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#verify cuda

# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !cp /content/drive/MyDrive/Undisputed_yolov3/obj.zip ../ #../ koduthal thott munpathe locationil aa folder kittum

# %%
pwd
# Out:
# '/content/darknet'

# %%
# !unzip ../obj.zip -d data/   #automatic aai oru puthiya folder darknetinu akath create aakum.
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/1ba50fbd8511e221f4f3a45c96a218d2.jpg
#   inflating: data/obj/2dd9c1ec18938a9f0c1f9cd3c763d628.jpg
#   inflating: data/obj/3bdbb103d411a25983f4606cc6a6af44.jpg
#   inflating: data/obj/6aa1f5e16b9ee957e3c1631f25c04de5.jpg
#   inflating: data/obj/8ae0fee7cca065b0f3f8e46ea53f5f21.jpg
#   inflating: data/obj/9c28b8a3ef0ea66ed21750e2d42ea066.jpg
#   inflating: data/obj/9cef2449526ac94db6379faa75489cff.jpg
#   inflating: data/obj/11fcbcdf46c6bac469dbb491d504edd7.jpg
#   inflating: data/obj/36d5c8cb4785afa4dab577988b684741.jpg
#   inflating: data/obj/58c846e30915ff5a3f6eae3b16eb037c.jpg
#   inflating: data/obj/65fdcfa9be757eb1e968b38e8a8347f8.jpg
#   inflating: data/obj/89fa2e496a85598e4e5fc6d9a58b21cc.jpg
#   inflating: data/obj/94fcd1325292e523b28eaa0e8647c06c.jpg
#   inflating: data/obj/199dfeb7d80dbd149f95360677c522d4.jpg
#   inflating: data/obj/951b7572b8e6e972d50cc480300ea69d.jpg
# ...

# %%
# !cp /content/drive/MyDrive/Undisputed_yolov3/obj.names ./data

# %%
# !cp /content/drive/MyDrive/Undisputed_yolov3/obj.data ./data

# %%
# !cp /content/drive/MyDrive/Undisputed_yolov3/yolov3_custom.cfg ./data

# %%
ls data/
# Out:
# 9k.tree     eagle.jpg    imagenet.labels.list      obj.data          scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names         voc.names
# coco.names  goal.txt     labels/                   openimages.names  yolov3_custom.cfg
# dog.jpg     horses.jpg   obj/                      person.jpg

# %%
# !python generate_train.py
# Out:
# python3: can't open file '/content/darknet/generate_train.py': [Errno 2] No such file or directory

# %%
# !cp '/content/drive/MyDrive/Undisputed_yolov3/generate_train.py' '/content/darknet/'

# %%
# !python generate_train.py

# %%
#download pretrained convolutional layer weight for transfer learning

# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-12-13 07:09:53--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  48.9MB/s    in 3.2s
#
# 2023-12-13 07:09:57 (48.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
pwd
# Out:
# '/content/darknet'

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/data/yolov3_custom.cfg /content/drive/MyDrive/undisputed_backup_yolov3/yolov3_custom_2000.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 76570, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.901954), count: 6, class_loss = 0.000207, iou_loss = 0.056082, total_loss = 0.056288
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.857944), count: 2, class_loss = 0.000447, iou_loss = 0.043570, total_loss = 0.044017
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 76578, rewritten_bbox = 0.000000 %
# ...
